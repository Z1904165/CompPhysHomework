# %% [markdown]
# <a href="https://colab.research.google.com/github/Z1904165/CompPhysHomework/blob/main/Hello_World_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello World

# %%
print("Hello World :)")
# Out:
# Hello World :)
